# %%
import pandas as pd

from pathlib import Path

# %%
#earthquake_df = pd.read_csv("CSV Data/archive/earthquake_1995-2023.csv")
earthquake_df = Path("CSV Data/archive/earthquake_1995-2023.csv")

# %%
earthquake_df= pd.read_csv(earthquake_df)

# %%
earthquake_df = pd.read_csv(csv_path)
earthquake_df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
# ...

# %%
earthquake_df.dtypes
# Out:
# title         object
# magnitude    float64
# date_time     object
# cdi            int64
# mmi            int64
# alert         object
# tsunami        int64
# sig            int64
# net           object
# nst            int64
# dmin         float64
# gap          float64
# magType       object
# depth        float64
# latitude     float64
# longitude    float64
# location      object
# continent     object
# country       object
# dtype: object

# %%
earthquake_df.drop(columns=['continent', 'mmi', 'dmin'], inplace=True)
earthquake_df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#     alert  tsunami  sig net  nst    gap magType    depth  latitude  longitude  \
# 0   green        0  657  us  114   25.0     mww  192.955  -13.8814   167.1580
# 1  yellow        0  775  us   92   40.0     mww   69.727   12.8140   -88.1265
# 2   green        0  899  us   70   28.0     mww  171.371  -38.1911   -70.3731
# 3   green        1  860  us  173   36.0     mww   32.571   54.3844  -160.6990
# 4     NaN        1  820  at   79  172.8      Mi   21.000   54.4900  -160.7960
#
# ...

# %%
earthquake_df.count()
# Out:
# title        1000
# magnitude    1000
# date_time    1000
# cdi          1000
# alert         449
# tsunami      1000
# sig          1000
# net          1000
# nst          1000
# gap          1000
# magType      1000
# depth        1000
# latitude     1000
# longitude    1000
# location      994
# country       651
# dtype: int64

# %%
earthquake_df['location'].value_counts()
# Out:
# Kokopo, Papua New Guinea     29
# Sola, Vanuatu                19
# Kirakira, Solomon Islands    18
# Panguna, Papua New Guinea    17
# Kimbe, Papua New Guinea      15
#                              ..
# Aniso, Peru                   1
# Piti Village, Guam            1
# Sangay, Philippines           1
# El Aguilar, Argentina         1
# Cabatuan, Philippines         1
# Name: location, Length: 502, dtype: int64

# %%
earthquake_df.isnull()
# Out:
#      title  magnitude  date_time    cdi  alert  tsunami    sig    net    nst  \
# 0    False      False      False  False  False    False  False  False  False
# 1    False      False      False  False  False    False  False  False  False
# 2    False      False      False  False  False    False  False  False  False
# 3    False      False      False  False  False    False  False  False  False
# 4    False      False      False  False   True    False  False  False  False
# ..     ...        ...        ...    ...    ...      ...    ...    ...    ...
# 995  False      False      False  False   True    False  False  False  False
# 996  False      False      False  False   True    False  False  False  False
# 997  False      False      False  False   True    False  False  False  False
# 998  False      False      False  False   True    False  False  False  False
# 999  False      False      False  False   True    False  False  False  False
#
# ...

# %%
earthquake_df.isnull().sum()
# Out:
# title          0
# magnitude      0
# date_time      0
# cdi            0
# alert        551
# tsunami        0
# sig            0
# net            0
# nst            0
# gap            0
# magType        0
# depth          0
# latitude       0
# longitude      0
# location       6
# country      349
# dtype: int64

# %%
earthquake_df.dropna(inplace=True)
earthquake_df
# Out:
#                                             title  magnitude  \
# 0                M 6.5 - 42 km W of Sola, Vanuatu        6.5
# 2        M 6.6 - 25 km ESE of Loncopué, Argentina        6.6
# 8           M 6.6 - Panama-Colombia border region        6.6
# 13   M 7.1 - 170 km SSE of Teluk Dalam, Indonesia        7.1
# 16            M 7.0 - 96 km N of Tuban, Indonesia        7.0
# ..                                            ...        ...
# 446    M 6.7 - 33 km SSW of Lata, Solomon Islands        6.7
# 447     M 7.0 - 33 km NW of Lata, Solomon Islands        7.0
# 450           M 6.9 - 18 km SSW of Obihiro, Japan        6.9
# 451            M 6.8 - 54 km N of Vallenar, Chile        6.8
# 542            M 7.2 - 12km SW of Delta, B.C., MX        7.2
#
#             date_time  cdi   alert  tsunami   sig net  nst    gap magType  \
# 0    16-08-2023 12:47    7   green        0   657  us  114   25.0     mww
# 2    17-07-2023 03:05    7   green        0   899  us   70   28.0     mww
# ...

# %%
earthquake_df.sort_values('location')
# Out:
#                                                  title  magnitude  \
# 225                   M 7.3 - 29 km S of ?alabja, Iraq        7.3
# 335                 M 6.8 - 32 km SE of ?funato, Japan        6.8
# 324             M 7.0 - 234 km W of Abepura, Indonesia        7.0
# 437           M 7.0 - 260 km WSW of Abepura, Indonesia        7.0
# 83                            M 7.0 - Acapulco, Mexico        7.0
# ..                                                 ...        ...
# 33                                     M 7.0 - Vanuatu        7.0
# 443           M 6.9 - 2 km NNE of Yacuanquer, Colombia        6.9
# 45                   M 6.9 - 90 km E of Yujing, Taiwan        6.9
# 74                     M 6.6 - northern Qinghai, China        6.6
# 17   M 6.5 - near the east coast of the Kamchatka P...        6.5
#
#             date_time  cdi   alert  tsunami   sig net  nst   gap magType  \
# 225  12-11-2017 18:18    8     red        0  2790  us    0  33.0     mww
# ...

# %%
earthquake_df.sort_values("gap", ascending=False)
# Out:
#                                               title  magnitude  \
# 542              M 7.2 - 12km SW of Delta, B.C., MX        7.2
# 209    M 6.9 - 18 km SSW of Leilani Estates, Hawaii        6.9
# 8             M 6.6 - Panama-Colombia border region        6.6
# 43           M 6.8 - 55 km SSW of Aguililla, Mexico        6.8
# 216  M 7.2 - 4 km S of Pinotepa de Don Luis, Mexico        7.2
# ..                                              ...        ...
# 306            M 6.5 - 19 km SSW of Lefkáda, Greece        6.5
# 418       M 6.5 - 29 km SE of Blenheim, New Zealand        6.5
# 182      M 7.1 - 1 km SE of Point MacKenzie, Alaska        7.1
# 294          M 7.1 - 47 km ESE of Pedro Bay, Alaska        7.1
# 79              M 6.9 - 112 km E of Chignik, Alaska        6.9
#
#             date_time  cdi   alert  tsunami   sig net  nst    gap magType  \
# 542  04-04-2010 22:40    9     red        0  2910  ci   10  239.0      mw
# ...
